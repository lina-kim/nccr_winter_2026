# %% [markdown]
# # Workshop: Assessment of Reusability
#
# Save your own local copy of this notebook by using File > Save a copy in Drive. At some point you may be prompted to trust the notebook. We promise that it is safe 🤞
#
# **Disclaimer:**
#
# The Google Colab notebook environment will interpret any command as Python code by default. If we want to run shell commands, we will have to prefix them by `!`. So any command you see with a leading `!` is a shell command and if you wanted to run it in your terminal you would omit the leading `!`. For example, if in the Colab notebook you ran `!wget` you would just run `wget` in your terminal.

# %% [markdown]
# ## Setup

# %% [markdown]
# Launch the following cell to set up the appropriate environment in your Jupyter Notebook:

# %%
! pip install git+https://github.com/bokulich-lab/mishmash.git@lxml_change

# %% [markdown]
# We will download some data files and switch to working within the `materials` directory for the rest of the notebook.

# %%
! git clone https://github.com/lina-kim/nccr_winter_2026.git materials/
% cd materials

# %% [markdown]
# ## Exercise 1: Run a known dataset
#
# Input data files can be found in `data/`.
#
# 🔍 **Question 1:** Open the data file you are assigned to and list the first three PMC IDs below:
# 1.
# 2.
# 3.
#
# 🔍 **Question 2:** Go to the article associated with each ID and record both the title and name of the first author below:
# 1.
# 2.
# 3.
#
# 🔍 **Question 3:** What kind of sequencing data (i.e. amplicon vs. shotgun metagenomic) do you expect to find with each paper? If you were to reuse these datasets, what other kinds of data would you need?
# 1.
# 2.
# 3.

# %% [markdown]
# Complete the below code block for your assigned dataset and execute the MISHMASH command.

# %%
! mishmash assess_sequences \
    --pmc_input_file \
    --output_file

# %% [markdown]
# ## Exercise 2: Evaluate a new research question
#
# Each group is given a category of publications to explore.
# 1. Create a search query on [PubMed](https://pubmed.ncbi.nlm.nih.gov/). Save your search results as a CSV.
# 2. Among your group members, split your search results by publication year.
# 3. Use MISHMASH to assess the reproducibility of sequence data from the papers in your publication year.
# 4. Compile your group's results and generate a figure to summarize your findings.
# 5. At the end, present your figure and explain your data.
